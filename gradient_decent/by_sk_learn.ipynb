# %%
from sklearn.datasets import make_regression
from sklearn.model_selection import cross_val_score

import matplotlib.pyplot as plt 
import numpy as np

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score

# %%
X,y = make_regression(n_samples=100, n_features=1, n_informative=1, n_targets=1, noise=20)


plt.scatter(X,y)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()
lr.fit(X,y)
# Out:
# LinearRegression()

# %%
lr.coef_
# Out:
# array([19.066132])

# %%
lr.intercept_
# Out:
# np.float64(1.0406269410285898)

# %%
m = 68.18

# %%
class GDregressor:
    def __init__(self, learning_rate=0.01, epochs=1000):
        self.m = 68.18
        self.b = -120
        self.learning_rate = learning_rate 
        self.epochs = epochs
        
    def fit(self, X, y):
        # calculate the b using GD
        for i in range(self.epochs):
            lose_slope = -2 * np.sum(y - self.m * X.ravel() - self.b)
            self.b = self.b - (self.learning_rate * lose_slope)
            
        print(self.b)

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2, random_state=69)

# %%
gd = GDregressor(0.001, 10000)
gd.fit(X_train,y_train)
# Out:
# coef : 88.0368989424881 intercept : 0.30358668584066645

# %%
y_pred = gd.predict(X_test)
r2_score(y_test, y_pred)
# wee need to keep our model and near to the data to get good score.
# Out:
# 0.5165462812988162

# %% [markdown]
# # Working with the 2d data

# %%
from sklearn.datasets import make_regression
import matplotlib.pyplot as plt

# %%
X, y = make_regression(n_samples=100, n_features=1, n_informative=1, n_targets=1, noise=20, random_state=69)

# %%
plt.scatter(X,y)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2, random_state=69)

# %%
lr.fit(X_train,y_train)

print(lr.coef_,lr.intercept_)
# Out:
# [88.03689897] 0.3035869334001271

# %%
y_pred = gd.predict(X_test)
r2_score(y_test, y_pred)
# Out:
# 0.5165462812988162

# %%
class GDregressor:
    def __init__(self, learning_rate=0.01, epochs=1000):
        self.m = 100.0
        self.b = -120.0
        self.learning_rate = learning_rate
        self.epochs = epochs

    def fit(self, X, y):
        Xr = X.ravel()
        n = Xr.shape[0]
        for _ in range(self.epochs):
            y_pred = self.m * Xr + self.b
            error = y - y_pred
            grad_b = -2.0 * np.sum(error) / n
            grad_m = -2.0 * np.sum(Xr * error) / n
            self.b = self.b - self.learning_rate * grad_b
            self.m = self.m - self.learning_rate * grad_m
        print("coef :", self.m, "intercept :", self.b)
        
    def predict(self, x):
        return self.m  * x * self.b

# %%
gd = GDregressor(0.001, 10000)

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2, random_state=69)

# %%
gd.fit(X_train,y_train)
# Out:
# coef : 88.0368989424881 intercept : 0.30358668584066645

# %%
y_pred = gd.predict(X_test)
r2_score(y_test, y_pred)
# Out:
# 0.5165462812988162
