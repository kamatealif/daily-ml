# %%
from sklearn.datasets import make_regression
from sklearn.model_selection import cross_val_score

import matplotlib.pyplot as plt 
import numpy as np

# %%
X,y = make_regression(n_samples=100, n_features=1, n_informative=1, n_targets=1, noise=20)


plt.scatter(X,y)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()
lr.fit(X,y)
# Out:
# LinearRegression()

# %%
lr.coef_
# Out:
# array([15.75954366])

# %%
lr.intercept_
# Out:
# np.float64(0.4662948201174272)

# %%
m = 68.18

# %%
class GDregressor:
    def __init__(self, learning_rate=0.01, epochs=1000):
        self.m = 68.18
        self.b = -120
        self.learning_rate = learning_rate 
        self.epochs = epochs
        
    def fit(self, X, y):
        # calculate the b using GD
        for i in range(self.epochs):
            lose_slope = -2 * np.sum(y - self.m * X.ravel() - self.b)
            self.b = self.b - (self.learning_rate * lose_slope)
            
        print(self.b)

# %%
gd = GDregressor(0.001, 10000)
gd.fit(X,y)
# Out:
# 0.38366026517841334

# %%
np.mean(cross_val_score(lr, X,y, scoring='r2', cv=10))
# wee need to keep our model and near to the data to get good score.
# Out:
# np.float64(0.9497130758297633)

# %% [markdown]
# # Working with the 2d data

# %%
from sklearn.datasets import make_regression
import matplotlib.pyplot as plt

# %%
X, y = make_regression(n_samples=100, n_features=1, n_informative=1, n_targets=1, noise=20, random_state=69)

# %%
plt.scatter(X,y)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(X,y)

print(lr.coef_,lr.intercept_)
# Out:
# [86.75575015] -0.23937084930071517

# %%
class GDregressor:
    def __init__(self, learning_rate=0.01, epochs=1000):
        self.m = 100.0
        self.b = -120.0
        self.learning_rate = learning_rate
        self.epochs = epochs

    def fit(self, X, y):
        Xr = X.ravel()
        n = Xr.shape[0]
        for _ in range(self.epochs):
            y_pred = self.m * Xr + self.b
            error = y - y_pred
            grad_b = -2.0 * np.sum(error) / n
            grad_m = -2.0 * np.sum(Xr * error) / n
            self.b = self.b - self.learning_rate * grad_b
            self.m = self.m - self.learning_rate * grad_m
        print("coef :", self.m, "intercept :", self.b)

# %%
gd = GDregressor(0.001, 10000)

# %%
gd.fit(X,y)
# Out:
# coef : 86.75575010454794 intercept : -0.23937111127167282
